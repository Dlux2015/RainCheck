# %% [markdown]
# # 04 — Train XGBoost Model

# %%
# xgboost is not pinned in DBR Free Edition at the version we need
# %pip install xgboost --quiet

# %%
import sys, os

REPO = '/Repos/david.lu.webdev@gmail.com/RainCheck/hurricane-gas-predictor'
if REPO not in sys.path:
    sys.path.insert(0, REPO)

assert os.path.isdir(os.path.join(REPO, 'src')), f'src/ not found at {REPO}'

from src.ml.train import train
run_id = train()
print('Run ID:', run_id)
