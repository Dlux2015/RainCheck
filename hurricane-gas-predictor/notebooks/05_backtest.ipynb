# %% [markdown]
# # 05 — Walk-Forward Backtest
#
# Evaluate the buy signal using walk-forward cross-validation on historical gold-layer data.
# Results are logged to MLflow.

# %%
import subprocess, sys
subprocess.run(['git', 'clone', '--depth=1', 'https://github.com/Dlux2015/RainCheck.git', '/tmp/raincheck'], capture_output=True)
if '/tmp/raincheck' not in sys.path:
    sys.path.insert(0, '/tmp/raincheck')

# %%
from src.ml.backtest import run_backtest
results = run_backtest(n_splits=5)

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(12, 4))
for ax, col in zip(axes, ['auc', 'precision', 'recall']):
    ax.bar(results['fold'], results[col])
    ax.set_title(col.upper())
    ax.set_ylim(0, 1)
plt.tight_layout()
plt.show()
