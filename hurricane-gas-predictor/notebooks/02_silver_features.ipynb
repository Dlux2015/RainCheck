# %% [markdown]
# # 02 — Bronze to Silver

# %%
# %pip install -e /Repos/david.lu.webdev@gmail.com/RainCheck/hurricane-gas-predictor --quiet

# %%
from src.transforms.bronze_to_silver import run
run()
